# %%
import sympy as sym
import jax.numpy as jnp
import jax
jax.config.update("jax_enable_x64",True)
from sympy import factorial
from sympy.plotting import plot
from sympy.series.series import series
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
p = 5
exp_multiplier = -sym.sqrt(2 * p + 1)
coefficients = [factorial(p + i) / (factorial(i) * factorial(p - i)) * (sym.sqrt(8 * p + 4))**(p - i) for i in range(p + 1)]
powers = list(range(p,-1,-1))
norm_cons = factorial(p)/factorial(2*p)


d = sym.symbols('d')
matern = norm_cons*sum([c * (d**power) for c,power in zip(coefficients,powers)])*sym.exp(exp_multiplier * d)

S = series(sym.log(matern),d,0,2*p+1).removeO()

plot(matern - sym.exp(S),(d,0,0.1))

# %%
polyS = sym.Poly(S,d)

coeffs = polyS.all_coeffs()
powers = polyS.monoms()

# %%
list(map(lambda x:x[0],powers))
# Out:
# [10, 8, 6, 4, 2]

# %%
p = 2
exp_multiplier = -sym.sqrt(2 * p + 1)
coefficients = [factorial(p + i) / (factorial(i) * factorial(p - i)) * (sym.sqrt(8 * p + 4))**(p - i) for i in range(p + 1)]
powers = list(range(p,-1,-1))
norm_cons = factorial(p)/factorial(2*p)

d = sym.symbols('d')
matern = norm_cons*sum([c * (d**power) for c,power in zip(coefficients,powers)])*sym.exp(exp_multiplier * d)



S = series(sym.log(matern),d,0,2*p+1).removeO()
polyS = sym.Poly(S,d)
asy_coeffs = polyS.coeffs()
asy_coeffs = jnp.array(list(map(float,asy_coeffs)))

asy_powers = polyS.monoms()
half_asy_powers = jnp.array(asy_powers)[:,0]//2

# %%
asy_coeffs
# Out:
# Array([ 0.69444444, -0.83333333], dtype=float64)

# %%
half_asy_powers
# Out:
# Array([2, 1], dtype=int64)

# %%
def setup_matern(p):
    exp_multiplier = -sym.sqrt(2 * p + 1)
    coefficients = [
        (factorial(p)/factorial(2*p)) * (factorial(p + i) / (factorial(i) * factorial(p - i)))
        * (sym.sqrt(8 * p + 4))**(p - i) 
        for i in range(p + 1)]
    powers = list(range(p,-1,-1))

    jax_coefficients = jnp.array(list(map(float,coefficients)))
    jax_powers = jnp.array(powers)
    jax_exp_multiplier = float(exp_multiplier)

    d = sym.symbols('d')
    matern = sum([c * (d**power) for c,power in zip(coefficients,powers)])*sym.exp(exp_multiplier * d)
    S = series(sym.log(matern),d,0,2*p+1).removeO()
    polyS = sym.Poly(S,d)
    asy_coeffs = polyS.coeffs()
    asy_coeffs = jnp.array(list(map(float,asy_coeffs)))

    asy_powers = polyS.monoms()
    half_asy_powers = jnp.array(asy_powers)[:,0]//2

    def matern_p_factory(rho):
        def matern_func(x,y):
            d2 = jnp.sum((x-y)**2)/(rho**2)
            d = jnp.sqrt(d2)
            true = jnp.sum(jax_coefficients*jnp.power(d,jax_powers))*jnp.exp(jax_exp_multiplier * d)
            asymptotic = jnp.exp(jnp.sum(asy_coeffs * jnp.power(d2,half_asy_powers)))
            return jnp.where(d2<1e-5, asymptotic, true)
        return matern_func
    
    return matern_p_factory

# %%
from KernelTools import vectorize_kfunc,make_block,dxx_k
import matplotlib.pyplot as plt

k = setup_matern(3)(1.)

# %%
grid = jnp.linspace(-0.0001,0.0001,1000)
values = vectorize_kfunc(k)(jnp.array([0.]),grid)[0]
plt.plot(grid,values)

# %%
k_modified = setup_matern(5)(1.)

vkphi = vectorize_kfunc(dxx_k(dxx_k(k_modified,0),1))
n = 500
zero = jnp.array([[0,0.]])

bound = 0.1
grid = jnp.vstack([jnp.zeros(n),jnp.linspace(-bound,bound,n)]).T

values = vkphi(zero,grid)[0]
plt.plot(grid[:,1],values)

# %%
from Kernels import get_matern
k_original = get_matern(5,1.)

# vkphi = vectorize_kfunc(dxx_k(dxx_k(k_original,0),1))
# vkphi = make_block(k_original,dxx_k,dxx_k)

vkphi = vectorize_kfunc(dxx_k(dxx_k(k_original,0),1))


n = 500
bound = 0.01
zero = jnp.array([[0,0.]])
grid = jnp.vstack([jnp.zeros(n),jnp.linspace(-bound,bound,n)]).T

values = vkphi(zero,grid)[0]
plt.plot(grid[:,1],values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:677, in dtype(x, canonicalize)
#     676 try:
# --> 677   dt = np.result_type(x)
#     678 except TypeError as err:
#
# TypeError: Cannot interpret '12841.9711882561' as a data type
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:3181, in array(object, dtype, copy, order, ndmin)
#    3180 try:
# -> 3181   dtype = dtypes._lattice_result_type(*leaves)[0] if leaves else dtypes.float_
#    3182 except TypeError:
#    3183   # This happens if, e.g. one of the entries is a memoryview object.
#    3184   # This is rare, so we only handle it if the normal path fails.
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in _lattice_result_type(*args)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in <genexpr>(.0)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:495, in _dtype_and_weaktype(value)
#     494 """Return a (dtype, weak_type) tuple for the given input."""
# --> 495 return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:679, in dtype(x, canonicalize)
#     678   except TypeError as err:
# --> 679     raise TypeError(f"Cannot determine dtype of {x}") from err
#     680 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
#
# TypeError: Cannot determine dtype of 12841.9711882561
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 from Kernels import get_matern
# ----> 2 k_original = get_matern(5,1.)
#       4 # vkphi = vectorize_kfunc(dxx_k(dxx_k(k_original,0),1))
#       5 # vkphi = make_block(k_original,dxx_k,dxx_k)
#       7 vkphi = vectorize_kfunc(dxx_k(dxx_k(k_original,0),1))
#
# File ~/keql/keql_tools/Kernels.py:101, in get_matern(p, rho)
#      74 """
#      75     Builds a Matern kernel function.
#      76
#    (...)
#      98                [0.82864914, 0.52399411]], dtype=float64)
#      99 """
#     100 exp_multiplier = -jnp.sqrt(2 * p + 1)
# --> 101 coefficients = jnp.array([factorial(p + i) / (factorial(i) * factorial(p - i)) * (jnp.sqrt(8 * p + 4))**(p - i) for i in range(p + 1)])
#     102 powers = jnp.arange(p,-1,-1)
#     103 norm_cons = factorial(p)/factorial(2*p)
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:3186, in array(object, dtype, copy, order, ndmin)
#    3182   except TypeError:
#    3183     # This happens if, e.g. one of the entries is a memoryview object.
#    3184     # This is rare, so we only handle it if the normal path fails.
#    3185     leaves = [_convert_to_array_if_dtype_fails(leaf) for leaf in leaves]
# -> 3186     dtype = dtypes._lattice_result_type(*leaves)[0]
#    3188 if not weak_type:
#    3189   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in _lattice_result_type(*args)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#     689     out_dtype = dtypes[0]
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in <genexpr>(.0)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#     689     out_dtype = dtypes[0]
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:495, in _dtype_and_weaktype(value)
#     493 def _dtype_and_weaktype(value: Any) -> tuple[DType, bool]:
#     494   """Return a (dtype, weak_type) tuple for the given input."""
# --> 495   return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:681, in dtype(x, canonicalize)
#     679     raise TypeError(f"Cannot determine dtype of {x}") from err
#     680 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
# --> 681   raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#     682                   "type. Only arrays of numeric types are supported by JAX.")
#     683 # TODO(jakevdp): fix return type annotation and remove this ignore.
#     684 return canonicalize_dtype(dt, allow_extended_dtype=True) if canonicalize else dt
#
# TypeError: Value '12841.9711882561' with dtype object is not a valid JAX array type. Only arrays of numeric types are supported by JAX.

# %%
k = get_matern(5,1.)


vkphi = vectorize_kfunc(dxx_k(dxx_k(k,0),1))
n = 500
zero = jnp.array([[0,0.]])
grid = jnp.vstack([jnp.zeros(n),jnp.linspace(-0.1,.1,n)]).T
plt.plot(grid[:,1],make_block(k,dxx_k,dxx_k)(zero,grid)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 k = get_matern(5,1.)
#       4 vkphi = vectorize_kfunc(dxx_k(dxx_k(k,0),1))
#       5 n = 500
#
# NameError: name 'get_matern' is not defined

# %%
from Kernels import (
    get_centered_scaled_poly_kernel,
    get_anisotropic_gaussianRBF,
    fit_kernel_params,
    get_matern
)

k = get_matern(3,1.)


vkphi = vectorize_kfunc(dxx_k(dxx_k(k,0),1))

bound = 0.0001
zero = jnp.array([[0,0.]])
grid = jnp.vstack([jnp.zeros(n),jnp.linspace(-bound,bound,n)]).T
plt.plot(grid[:,1],make_block(k,dxx_k,dxx_k)(zero,grid)[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:677, in dtype(x, canonicalize)
#     676 try:
# --> 677   dt = np.result_type(x)
#     678 except TypeError as err:
#
# TypeError: Cannot interpret '148.162073419617' as a data type
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:3181, in array(object, dtype, copy, order, ndmin)
#    3180 try:
# -> 3181   dtype = dtypes._lattice_result_type(*leaves)[0] if leaves else dtypes.float_
#    3182 except TypeError:
#    3183   # This happens if, e.g. one of the entries is a memoryview object.
#    3184   # This is rare, so we only handle it if the normal path fails.
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in _lattice_result_type(*args)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in <genexpr>(.0)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:495, in _dtype_and_weaktype(value)
#     494 """Return a (dtype, weak_type) tuple for the given input."""
# --> 495 return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:679, in dtype(x, canonicalize)
#     678   except TypeError as err:
# --> 679     raise TypeError(f"Cannot determine dtype of {x}") from err
#     680 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
#
# TypeError: Cannot determine dtype of 148.162073419617
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       1 from Kernels import (
#       2     get_centered_scaled_poly_kernel,
#       3     get_anisotropic_gaussianRBF,
#       4     fit_kernel_params,
#       5     get_matern
#       6 )
# ----> 8 k = get_matern(3,1.)
#      11 vkphi = vectorize_kfunc(dxx_k(dxx_k(k,0),1))
#      13 bound = 0.0001
#
# File ~/keql/keql_tools/Kernels.py:101, in get_matern(p, rho)
#      74 """
#      75     Builds a Matern kernel function.
#      76
#    (...)
#      98                [0.82864914, 0.52399411]], dtype=float64)
#      99 """
#     100 exp_multiplier = -jnp.sqrt(2 * p + 1)
# --> 101 coefficients = jnp.array([factorial(p + i) / (factorial(i) * factorial(p - i)) * (jnp.sqrt(8 * p + 4))**(p - i) for i in range(p + 1)])
#     102 powers = jnp.arange(p,-1,-1)
#     103 norm_cons = factorial(p)/factorial(2*p)
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:3186, in array(object, dtype, copy, order, ndmin)
#    3182   except TypeError:
#    3183     # This happens if, e.g. one of the entries is a memoryview object.
#    3184     # This is rare, so we only handle it if the normal path fails.
#    3185     leaves = [_convert_to_array_if_dtype_fails(leaf) for leaf in leaves]
# -> 3186     dtype = dtypes._lattice_result_type(*leaves)[0]
#    3188 if not weak_type:
#    3189   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in _lattice_result_type(*args)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#     689     out_dtype = dtypes[0]
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:687, in <genexpr>(.0)
#     686 def _lattice_result_type(*args: Any) -> tuple[DType, bool]:
# --> 687   dtypes, weak_types = zip(*(_dtype_and_weaktype(arg) for arg in args))
#     688   if len(dtypes) == 1:
#     689     out_dtype = dtypes[0]
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:495, in _dtype_and_weaktype(value)
#     493 def _dtype_and_weaktype(value: Any) -> tuple[DType, bool]:
#     494   """Return a (dtype, weak_type) tuple for the given input."""
# --> 495   return dtype(value), any(value is typ for typ in _weak_types) or is_weakly_typed(value)
#
# File ~/miniconda3/envs/alex_keql/lib/python3.12/site-packages/jax/_src/dtypes.py:681, in dtype(x, canonicalize)
#     679     raise TypeError(f"Cannot determine dtype of {x}") from err
#     680 if dt not in _jax_dtype_set and not issubdtype(dt, extended):
# --> 681   raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#     682                   "type. Only arrays of numeric types are supported by JAX.")
#     683 # TODO(jakevdp): fix return type annotation and remove this ignore.
#     684 return canonicalize_dtype(dt, allow_extended_dtype=True) if canonicalize else dt
#
# TypeError: Value '148.162073419617' with dtype object is not a valid JAX array type. Only arrays of numeric types are supported by JAX.

# %%
from KernelTools import vectorize_kfunc,dxx_k,make_block
from Kernels import (
    get_centered_scaled_poly_kernel,
    get_anisotropic_gaussianRBF,
    fit_kernel_params,
    get_matern
)
from Kernels import get_gaussianRBF

import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.special import factorial

def get_matern(p,rho):
    """
        Builds a Matern kernel function.

        Args:
            p (int): As used in smoothness nu = p + 1/2.
            rho (double): Length scale of the Matern kernel.

        Returns:
            function: This function returns the Matern kernel with smoothness p+1/2 and lengthscale rho.   
    """
    exp_multiplier = -jnp.sqrt(2 * p + 1)
    coefficients = jnp.array([factorial(p + i) / (factorial(i) * factorial(p - i)) * (jnp.sqrt(8 * p + 4))**(p - i) for i in range(p + 1)])
    powers = jnp.arange(p,-1,-1)
    norm_cons = factorial(p)/factorial(2*p)
    def k(x,y):
        # True 
        d2 = jnp.sum((x-y)**2)/rho**2
        d = jnp.sqrt(d2+1e-100)
        true =  norm_cons*jnp.sum(coefficients * jnp.power(d,powers))*jnp.exp(exp_multiplier * d)
        #  Taylor
        nu = p + 1/2
        taylor = 1 + (nu/(2*(1-nu))*d2 + nu**2/(8*(2-3*nu+nu**2))*(d2)**2)
        return jnp.where(d2<1e-5, taylor, true)
    return k


k = get_matern(5,1.)


vkphi = vectorize_kfunc(dxx_k(dxx_k(k,0),1))
n = 500
zero = jnp.array([[0,0.]])
bound = 1e-2
grid = jnp.vstack([jnp.zeros(n),jnp.linspace(-bound,bound,n)]).T
plt.plot(grid[:,1],make_block(k,dxx_k,dxx_k)(zero,grid)[0])
