# %%
import jax
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_device", jax.devices()[2])

import jax.numpy as jnp
from KernelTools import make_block,eval_k,vectorize_kfunc,diagpart,get_selected_grad
from Kernels import get_gaussianRBF,get_centered_scaled_poly_kernel
from data_utils import build_xy_grid
from darcy_data import get_darcy_solver,sample_gp_function
from jax.random import PRNGKey as pkey
import matplotlib.pyplot as plt
from EquationModel import CholInducedRKHS,OperatorPDEModel,InducedOperatorModel
from tqdm.auto import tqdm

# %%
num_functions = 60
samples_per_function = 10
obs_random_keys = jax.random.split(pkey(32),num_functions)
xy_obs = tuple(jax.random.uniform(key,(samples_per_function,2),minval = 0.,maxval = 1.) for key in obs_random_keys)


kernel_f = get_gaussianRBF(0.15)
key = pkey(10)
keys = jax.random.split(key,num_functions)
rhs_functions = tuple(
    sample_gp_function(subkey,kernel_f) for subkey in keys
)

grid = jnp.linspace(0,1,100)
x,y = jnp.meshgrid(grid,grid)
fine_grid = jnp.vstack([x.flatten(),y.flatten()]).T

def a(x):
    return 0.1 * jnp.exp(0.5 * jnp.sin(4*jnp.pi*x[0]*x[1]))

darcy_solve = get_darcy_solver(a,num_grid = 50,k_u = get_gaussianRBF(0.2))
u_true_functions = tuple([darcy_solve(f) for f in rhs_functions])

# %%
num_to_plot = 2
plt.figure(figsize=(8,4))
plt.title("Permeability a(x,y)")
plt.tricontourf(fine_grid[:,0],fine_grid[:,1],jax.vmap(a)(fine_grid),100)
plt.colorbar()
plt.show()
plt.figure(figsize = (8,num_to_plot * 4))
for i in range(num_to_plot):
    plt.subplot(num_to_plot,2,2*i+1)
    plt.title("f")
    plt.tricontourf(fine_grid[:,0],fine_grid[:,1],jax.vmap(rhs_functions[i])(fine_grid),100)
    plt.colorbar()
    plt.subplot(num_to_plot,2,2*(i+1))
    plt.title('u')
    plt.tricontourf(fine_grid[:,0],fine_grid[:,1],jax.vmap(u_true_functions[i])(fine_grid),100)
    plt.colorbar()
plt.show()

# %%
k_u = get_gaussianRBF(0.2)
xy_int,xy_bdy=build_xy_grid([0,1],[0,1],25,25)
xy_all = jnp.vstack([xy_int,xy_bdy])


# plt.title('u')
# plt.tricontourf(fine_grid[:,0],fine_grid[:,1],jax.vmap(u_true_functions[0])(fine_grid),100)
# plt.colorbar()
# plt.scatter(xy_int[:,0],xy_int[:,1],c = 'black',s = 3)
# plt.scatter(xy_obs[:,0],xy_obs[:,1],c = 'red',s = 50,alpha = 0.8)
# plt.show()

# %%
def diff_x_op(k,index):
    return get_selected_grad(k,index,0)

def diff_xx_op(k,index):
    return get_selected_grad(get_selected_grad(k,index,0),index,0)

def diff_y_op(k,index):
    return get_selected_grad(k,index,1)

def diff_yy_op(k,index):
    return get_selected_grad(get_selected_grad(k,index,1),index,1)

def diff_xy_op(k,index):
    return get_selected_grad(get_selected_grad(k,index,0),index,1)

feature_operators = tuple([eval_k,diff_x_op,diff_xx_op,diff_y_op,diff_yy_op,diff_xy_op])
basis_operators = tuple([eval_k,diff_xx_op,diff_yy_op])

u_models = tuple([CholInducedRKHS(
    xy_all,
    basis_operators,
    k_u
    ) for i in range(num_functions)])


observation_points = tuple(jnp.vstack([xy_bdy,obs]) for obs in xy_obs)
observation_values = tuple(jax.vmap(u)(obs_loc) for u,obs_loc in zip(u_true_functions,observation_points))
collocation_points = (xy_int,)*num_functions

rhs_values = tuple(jax.vmap(rhs_func)(int_points) for rhs_func,int_points in zip(rhs_functions,collocation_points))

all_u_params_init = tuple([
    model.get_fitted_params(obs_loc,obs_val) 
    for obs_loc,obs_val,model in zip(observation_points,observation_values,u_models)
    ]
    )

grid_features_u_init = [(
    model.evaluate_operators(feature_operators,xy_int,model_params)).reshape(
            len(xy_int),
            len(feature_operators),
            order = 'F'
        ) for model,model_params in zip(u_models,all_u_params_init)
        ]
grid_features_u_init = jnp.vstack([jnp.hstack([xy_int,features]) for features in grid_features_u_init])

num_P_inducing = 250
input_feature_sample = jax.random.choice(pkey(320),grid_features_u_init,(num_P_inducing,))
k_P_u_part = get_centered_scaled_poly_kernel(1,grid_features_u_init[:,2:],c=1)
k_P_x_part = get_gaussianRBF(0.25)
def k_P(x,y):
    return k_P_x_part(x[:2],y[:2]) * k_P_u_part(x[2:],y[2:])

P_model = InducedOperatorModel(input_feature_sample,k_P)
P_init = P_model.get_fitted_params(grid_features_u_init,jnp.hstack(rhs_values),lam = 1e-6)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 39
#      30 rhs_values = tuple(jax.vmap(rhs_func)(int_points) for rhs_func,int_points in zip(rhs_functions,collocation_points))
#      32 all_u_params_init = tuple([
#      33     model.get_fitted_params(obs_loc,obs_val)
#      34     for obs_loc,obs_val,model in zip(observation_points,observation_values,u_models)
#      35     ]
#      36     )
#      38 grid_features_u_init = [(
# ---> 39     model.evaluate_operators(feature_operators,xy_int,model_params)).reshape(
#      40             len(xy_int),
#      41             len(feature_operators),
#      42             order = 'F'
#      43         ) for model,model_params in zip(u_models,all_u_params_init)
#      44         ]
#      45 grid_features_u_init = jnp.vstack([jnp.hstack([xy_int,features]) for features in grid_features_u_init])
#      47 num_P_inducing = 250
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/pjit.py:338, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
# --> 338 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     339     fun, jit_info, *args, **kwargs)
#     340 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     341 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/pjit.py:178, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     177 def _python_pjit_helper(fun, jit_info, *args, **kwargs):
# --> 178   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     180   for arg in args_flat:
#     181     dispatch.check_arg(arg)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/pjit.py:744, in _infer_params(fun, ji, args, kwargs)
#     741 entry = _infer_params_cached(
#     742     fun, ji, signature, avals, pjit_mesh, resource_env)
#     743 if entry.pjit_params is None:
# --> 744   p, args_flat = _infer_params_impl(
#     745       fun, ji, pjit_mesh, resource_env, args, kwargs, in_avals=avals)
#     746   if p.attrs_tracked:
#     747     # If there are attrs_tracked, don't use the cache.
#     748     return p, p.consts + args_flat
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/pjit.py:641, in _infer_params_impl(***failed resolving arguments***)
#     635 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     636     in_shardings_treedef, in_shardings_leaves,
#     637     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     638     in_avals, in_tree, dbg, device_or_backend_set, have_kwargs)
#     640 attr_token = _attr_token(flat_fun, in_type)
# --> 641 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     642     flat_fun, in_type, attr_token, dbg,
#     643     HashableFunction(res_paths, closure=()),
#     644     IgnoreKey(ji.inline))
#     645 _attr_update(flat_fun, in_type, attr_token, attrs_tracked)
#     647 out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     648     out_shardings_treedef, out_shardings_leaves, ji.out_layouts_treedef,
#     649     ji.out_layouts_leaves, HashableFunction(out_tree, closure=()),
#     650     tuple(out_avals), jaxpr.jaxpr.debug_info, device_or_backend_set)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/linear_util.py:352, in cache.<locals>.memoized_fun(fun, *args)
#     350   fun.populate_stores(stores)
#     351 else:
# --> 352   ans = call(fun, *args)
#     353   if explain and config.explain_cache_misses.value:
#     354     explain(fun.f, cache is new_cache, cache, key)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/pjit.py:1288, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1286     attrs_tracked = []
#    1287   else:
# -> 1288     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1289         fun, in_type, debug_info=pe_debug)
#    1290     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1291
#    1292 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1293 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2278, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2276 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2277   main.jaxpr_stack = ()  # type: ignore
# -> 2278   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2279     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2280   del main, fun
#    2281 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2301, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2299 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2300 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2301 ans = fun.call_wrapped(*in_tracers_)
#    2302 out_tracers = map(trace.full_raise, ans)
#    2303 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/kernelequationlearning/keql_tools/EquationModel.py:42, in CholInducedRKHS.evaluate_operators(self, operators, eval_points, params)
#      40 @partial(jit, static_argnames=['self','operators'])
#      41 def evaluate_operators(self,operators,eval_points,params):
# ---> 42     return get_kernel_block_ops(self.k,operators,self.operators)(eval_points,self.basis_points)@solve_triangular(self.cholT,params)
#
# File ~/kernelequationlearning/keql_tools/KernelTools.py:23, in get_kernel_block_ops.<locals>.k_super(x, y)
#      19 def k_super(x,y):
#      20     I = jnp.eye(output_dim)
#      21     blocks = (
#      22         [
# ---> 23             [jnp.kron(make_block(k,L_op,R_op)(x,y),I) for R_op in ops_right]
#      24             for L_op in ops_left
#      25         ]
#      26     )
#      27     return jnp.block(blocks)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/api.py:992, in vmap.<locals>.vmap_f(*args, **kwargs)
#     989 axis_size_ = (axis_size if axis_size is not None else
#     990               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
#     991 try:
# --> 992   out_flat = batching.batch(
#     993       flat_fun, axis_name, axis_size_, in_axes_flat,
#     994       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#     995       spmd_axis_name=spmd_axis_name
#     996   ).call_wrapped(*args_flat)
#     997 except batching.SpecMatchError as e:
#     998   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/api.py:992, in vmap.<locals>.vmap_f(*args, **kwargs)
#     989 axis_size_ = (axis_size if axis_size is not None else
#     990               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
#     991 try:
# --> 992   out_flat = batching.batch(
#     993       flat_fun, axis_name, axis_size_, in_axes_flat,
#     994       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#     995       spmd_axis_name=spmd_axis_name
#     996   ).call_wrapped(*args_flat)
#     997 except batching.SpecMatchError as e:
#     998   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/kernelequationlearning/keql_tools/KernelTools.py:42, in get_selected_grad.<locals>.selgrad(*args)
#      41 def selgrad(*args):
# ---> 42     return gradf(*args)[selected_index]
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/api.py:392, in grad.<locals>.grad_f(*args, **kwargs)
#     389 @wraps(fun, docstr=docstr, argnums=argnums)
#     390 @api_boundary
#     391 def grad_f(*args, **kwargs):
# --> 392   _, g = value_and_grad_f(*args, **kwargs)
#     393   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/api.py:468, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     466 _check_scalar(ans)
#     467 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 468 g = vjp_py(lax_internal._one(ans))
#     469 g = g[0] if isinstance(argnums, int) else g
#     470 if not has_aux:
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/api.py:1886, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    1879   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    1880       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    1881     raise ValueError(
#    1882         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    1883         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    1884         f"because the corresponding output of the function {name} had JAX type "
#    1885         f"{aval.str_short()}")
# -> 1886 ans = fun(*args)
#    1887 return tree_unflatten(out_tree, ans)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:149, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     147 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     148 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 149 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     150 return map(instantiate_zeros, arg_cts)
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:229, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     226   cts_in, = map(read_cotangent, eqn.outvars)
#     227 name_stack = source_info_util.current_name_stack() + eqn.source_info.name_stack
#     228 with source_info_util.user_context(
# --> 229     eqn.source_info.traceback, name_stack=name_stack), eqn.ctx.manager:
#     230   if eqn.primitive.call_primitive or eqn.primitive.map_primitive:
#     231     cts_in_avals = [v.aval for v in eqn.outvars]
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/core.py:279, in JaxprEqnContext.manager(self)
#     276 @property
#     277 @contextmanager
#     278 def manager(self):
# --> 279   with ExitStack() as stack:
#     280     for manager, val in self._managers:
#     281       stack.enter_context(manager(val))
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/contextlib.py:619, in ExitStack.__exit__(self, *exc_details)
#     615 try:
#     616     # bare "raise exc" replaces our carefully
#     617     # set-up context
#     618     fixed_ctx = exc.__context__
# --> 619     raise exc
#     620 except BaseException:
#     621     exc.__context__ = fixed_ctx
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/contextlib.py:604, in ExitStack.__exit__(self, *exc_details)
#     602 else:
#     603     exc_details = type(exc), exc, exc.__traceback__
# --> 604 if cb(*exc_details):
#     605     suppressed_exc = True
#     606     pending_raise = False
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~/miniconda3/envs/kernel_eq/lib/python3.13/site-packages/jax/_src/xla_metadata.py:53, in set_xla_metadata(*args, **kwargs)
#      49 finally:
#      50   thread_local_metadata.val = prev_metadata
#      51   config.update_thread_local_jit_state(
#      52       xla_metadata_context_manager=tuple(
# ---> 53           (v, k) for k, v in sorted(prev_metadata.items())
#      54       )
#      55   )
#
# KeyboardInterrupt:

# %%
params_init = jnp.hstack(list(all_u_params_init)+[P_init])
EqnModel  = OperatorPDEModel(
    P_model,
    u_models,
    observation_points,
    observation_values,
    collocation_points,
    feature_operators,
    rhs_values,
    datafit_weight = 20.,
    num_P_operator_params=250
)

# %%
from jaxopt import LBFGS

def run_jax_solver(solver, x0):
    state = solver.init_state(x0)
    sol = x0
    values, errors, stepsizes = [state.value], [state.error], [state.stepsize]

    def update(sol, state):
        return solver.update(sol, state)

    jitted_update = jax.jit(update)
    for iter_num in tqdm(range(solver.maxiter)):
        sol, state = jitted_update(sol, state)
        values.append(state.value)
        errors.append(state.error)
        stepsizes.append(state.stepsize)
        if solver.verbose > 0:
            print("Gradient Norm: ", state.error)
            print("Loss Value: ", state.value)
        if state.error <= solver.tol:
            break
        if stepsizes[-1] == 0:
            print("Restart")
            state = solver.init_state(sol)
    convergence_data = {
        "values": jnp.array(values),
        "gradnorms": jnp.array(errors),
        "stepsizes": jnp.array(stepsizes),
    }
    return sol, convergence_data, state

# %%
m_init = 0 * params_init
gamma = 0.7

@jax.jit
def scan_fn(carry, _):
    params, m = carry
    loss_val, g = jit_valgrad(params)
    m_new = (1 - gamma) * m + gamma * g
    d = g + m_new
    params_new = params - (6e-3) * d
    carry_new = (params_new, m_new)
    return carry_new, loss_val  # loss_val will be collected in the output

# Run the scan over 1000 iterations
(carry_final, losses) = jax.lax.scan(
    scan_fn,
    init=(params_init, m_init),
    xs=None,
    length=1000
)

# Extract the final parameters and momentum
params_final, m_final = carry_final

# %%
jit_valgrad = jax.jit(jax.value_and_grad(EqnModel.loss))
lbfgs = LBFGS(fun=jit_valgrad,value_and_grad = True, maxiter=5000,tol = 1e-6,history_size = 40)
lbfgs_sol,lbfgs_conv,state = run_jax_solver(lbfgs,params_init)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
plt.style.use('ggplot')
plt.plot(lbfgs_conv['values'])
#plt.plot(losses)
plt.yscale('log')

# %%
plt.style.use('ggplot')
plt.plot(lbfgs_conv['values'])
plt.plot(losses)
plt.yscale('log')

# %%
P_params = EqnModel.get_P_params(lbfgs_sol)
u_params = EqnModel.get_u_params(lbfgs_sol)

# %%
def build_darcy_op(a):
    def darcy_op(k,index):
        gradk = jax.grad(k,argnums = index)
        def agradk(*args):
            return a(args[index])*gradk(*args)
        def darcy_result(*args):
            return jnp.trace(jax.jacfwd(agradk,argnums = index)(*args))
        return darcy_result
    return darcy_op
darcy_op = build_darcy_op(a)

# %%
grid = jnp.linspace(0.0001,0.999,50)
x,y = jnp.meshgrid(grid,grid)
fine_grid_int = jnp.vstack([x.flatten(),y.flatten()]).T

# %%
eqnFeatures = EqnModel.single_eqn_features(u_models[0],u_params[0],fine_grid_int)
Phat_uhat = P_model.predict(eqnFeatures,P_params)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.tricontourf(fine_grid_int[:,0],fine_grid_int[:,1],jax.vmap(rhs_functions[0])(fine_grid_int),100)
plt.subplot(1,2,2)
plt.tricontourf(fine_grid_int[:,0],fine_grid_int[:,1],Phat_uhat,100)
plt.show()
plt.tricontourf(fine_grid_int[:,0],fine_grid_int[:,1],jax.vmap(rhs_functions[0])(fine_grid_int) - Phat_uhat,100)
plt.colorbar()
plt.scatter(xy_int[:,0],xy_int[:,1],c = 'black',s = 10)
plt.show()

# %%
jnp.linalg.norm(jax.vmap(rhs_functions[0])(fine_grid_int) - Phat_uhat)/jnp.linalg.norm(jax.vmap(rhs_functions[0])(fine_grid_int))
# Out:
# Array(0.02301436, dtype=float64)

# %%
percent_errors = []
for i in range(num_functions):
    u_vals = u_models[i].point_evaluate(fine_grid_int,u_params[i])
    u_true_vals = jax.vmap(u_true_functions[i])(fine_grid_int)
    percent_errors.append(jnp.linalg.norm(u_vals - u_true_vals)/jnp.linalg.norm(u_true_vals))

# %%
jnp.mean(jnp.array(percent_errors))
# Out:
# Array(0.04618082, dtype=float64)

# %%
plt.hist(percent_errors,10)
plt.show()

# %%
u_models[0].point_evaluate(jnp.array([[1,0.2]]),u_params[0])
# Out:
# Array([0.00022332], dtype=float64)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.tricontourf(fine_grid_int[:,0],fine_grid_int[:,1],u_true_vals,100)
plt.colorbar()
plt.subplot(1,2,2)
plt.tricontourf(fine_grid_int[:,0],fine_grid_int[:,1],u_vals,100)
plt.colorbar()
plt.scatter(xy_obs[-1][:,0],xy_obs[-1][:,1])
plt.scatter(xy_bdy[:,0],xy_bdy[:,1])
plt.show()
plt.tricontourf(fine_grid_int[:,0],fine_grid_int[:,1],u_vals - u_true_vals,100)
plt.colorbar()
plt.scatter(xy_int[:,0],xy_int[:,1],c = 'black',s = 10)
